# %% [markdown]
# <center><img src="https://github.com/vadim0912/MLbase_2021_spring/blob/main/lecture04/images/header.png?raw=1" width=400></center>
#
# <h1><center>Основы машинного обучения</center></h1>
# <hr>
# <h2><center>Методы обучения без учителя: Домашняя работа</center></h2>

# %% [markdown]
# Правила:
#
# * Отчеты принимаются до 23:59 11 апреля. Вы должны залить ваш ноутбук в [colab](https://colab.research.google.com) и дать на него ссылку в форме сдачи ДЗ на портале
# * Работоспособность будет проверяться в коллабе. Это значит что:
#     1. Вам надо удостовериться, что код отрабатывает от начала и до конца. Выполните аналог "Restart Kernel and Run All" в colab
#     2. Убедитесь, что данные автоматически подгружается с помощью команды `!wget` (см семинары для примера). Все нужные данные есть [здесь](https://github.com/vadim0912/MLbase_2021_spring/tree/master/lecture04/data)
#     3. Все необходимые модули тоже устанавливаются на лету через `!pip`

# %%
# %matplotlib inline

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('seaborn-talk')
plt.rcParams['figure.figsize'] = (15,10)

# %%
# !mkdir ./data
# !wget https://raw.githubusercontent.com/vadim0912/MLbase_2021_spring/main/lecture04/data/sign_database.csv -O ./data/sign_database.csv
# !wget https://raw.githubusercontent.com/vadim0912/MLbase_2021_spring/main/lecture04/data/sign_classes.csv -O ./data/sign_classes.csv
# !wget https://raw.githubusercontent.com/vadim0912/MLbase_2021_spring/main/lecture04/data/news.csv -O ./data/news.csv
# Out:
# mkdir: cannot create directory ‘./data’: File exists
# --2021-04-24 16:13:44--  https://raw.githubusercontent.com/vadim0912/MLbase_2021_spring/main/lecture04/data/sign_database.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 32681203 (31M) [text/plain]
# Saving to: ‘./data/sign_database.csv’
#
# ./data/sign_databas 100%[===================>]  31.17M  56.7MB/s    in 0.5s
#
# 2021-04-24 16:13:45 (56.7 MB/s) - ‘./data/sign_database.csv’ saved [32681203/32681203]
#
# --2021-04-24 16:13:45--  https://raw.githubusercontent.com/vadim0912/MLbase_2021_spring/main/lecture04/data/sign_classes.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 26979 (26K) [text/plain]
# Saving to: ‘./data/sign_classes.csv’
#
# ./data/sign_classes 100%[===================>]  26.35K  --.-KB/s    in 0.002s
#
# 2021-04-24 16:13:45 (16.5 MB/s) - ‘./data/sign_classes.csv’ saved [26979/26979]
#
# --2021-04-24 16:13:45--  https://raw.githubusercontent.com/vadim0912/MLbase_2021_spring/main/lecture04/data/news.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13352242 (13M) [text/plain]
# Saving to: ‘./data/news.csv’
#
# ./data/news.csv     100%[===================>]  12.73M  33.9MB/s    in 0.4s
#
# 2021-04-24 16:13:46 (33.9 MB/s) - ‘./data/news.csv’ saved [13352242/13352242]

# %% [markdown]
# # Задача про датчики на руках

# %% [markdown]
# В этом задании мы применим метод главных компонент на многомерных данных и постараемся найти оптимальную размерность признаков для решения задачи классификации

# %% [markdown]
# Исходными [данными](http://archive.ics.uci.edu/ml/machine-learning-databases/auslan2-mld/auslan.data.html) являются показания различных сенсоров, установленных на руках человека, который умеет общаться на языке жестов.
#
# В данном случае задача ставится следующим образом: по показаниям датчиков (по 11 сенсоров на каждую руку) определить слово, которое было показано человеком.
#
# Как можно решать такую задачу?
#
# Показания датчиков представляются в виде временных рядов. Посмотрим на показания для одного из "слов"

# %%
# Загружаем данные сенсоров
df_database = pd.read_csv('./data/sign_database.csv')

# Загружаем метки классов
sign_classes = pd.read_csv('./data/sign_classes.csv', index_col=0, header=0, names=['id', 'class'])

# %%
# Столбец id - идентификаторы "слов"
# Столбец time - метка времени
# Остальные столбцы - показания серсоров для слова id в момент времени time

df_database.head()
# Out:
#         x_l       x_r       y_l       y_r  ...  little_l  little_r  id  time
# 0 -0.097816 -0.127761 -0.029051  0.537977  ...       0.0  0.133088   0     0
# 1 -0.102460 -0.126734 -0.029230  0.537758  ...       0.0  0.084865   0     1
# 2 -0.103085 -0.125618 -0.028605  0.537464  ...       0.0  0.026230   0     2
# 3 -0.102639 -0.126020 -0.028873  0.537306  ...       0.0  0.015033   0     3
# 4 -0.105139 -0.127538 -0.028917  0.537513  ...       0.0  0.000815   0     4
#
# [5 rows x 24 columns]

# %%
# Выберем одно из слов с идентификатором = 0
sign0 = df_database.query('id == 0')\
                   .drop(['id'], axis=1)\
                   .set_index('time')

# %%
sign0.plot()

# %% [markdown]
# Для каждого из "слов" у нас есть набор показаний сенсоров с разных частей руки в каждый момент времени.
#
# Идея нашего подхода будет заключаться в следующем – давайте для каждого сенсора составим набор характеристик (например, разброс значений, максимальное, минимальное, среднее значение, количество "пиков", и т.п.) и будем использовать эти новые "признаки" для решения задачи классификации.

# %% [markdown]
# ## Расчет новых признаков

# %% [markdown]
# Признаки мы будем считать с помощью библиотеки [tsfresh](http://tsfresh.readthedocs.io/en/latest/index.html). Генерация новых признаков может занять много времени, поэтому мы сохранили посчитанные данные, но при желании вы можете повторить вычисления.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
# # Если не хотите долго ждать - не убирайте комментарии
# !pip install tsfresh
# !pip install scipy>=1.5
# !pip install stumpy


# import tsfresh
# from tsfresh.feature_extraction import extract_features
# from tsfresh.feature_selection import select_features
# from tsfresh.utilities.dataframe_functions import impute
# from tsfresh.feature_extraction import ComprehensiveFCParameters, MinimalFCParameters, settings, EfficientFCParameters


# sign_features = extract_features(df_database, column_id='id', column_sort='time',
#                                  default_fc_parameters=EfficientFCParameters(),
#                                  impute_function=impute)

# enc = LabelEncoder()
# enc.fit(sign_classes.loc[:, 'class'])
# sign_classes.loc[:, 'target'] = enc.transform(sign_classes.loc[:, 'class'])

# sign_features_filtered = select_features(sign_features, sign_classes.loc[:, 'target'])

# filepath = './data/tsfresh_features_filt.csv.gz'
# sign_features_filtered.to_csv(filepath, compression='gzip')

# %%
# !mkdir ./data
# !wget https://www.dropbox.com/s/x6b9mqxlw5ijcuf/tsfresh_features_filt.csv.gz?dl=0 -O ./data/tsfresh_features_filt.csv.gz
filepath = './data/tsfresh_features_filt.csv.gz'
sign_features_filtered = pd.read_csv(filepath)
# Out:
# mkdir: cannot create directory ‘./data’: File exists
# --2021-04-24 16:13:47--  https://www.dropbox.com/s/x6b9mqxlw5ijcuf/tsfresh_features_filt.csv.gz?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.5.18, 2620:100:601d:18::a27d:512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.5.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/x6b9mqxlw5ijcuf/tsfresh_features_filt.csv.gz [following]
# --2021-04-24 16:13:48--  https://www.dropbox.com/s/raw/x6b9mqxlw5ijcuf/tsfresh_features_filt.csv.gz
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://u
dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 198183650 (189M) [application/octet-stream]
# Saving to: ‘./data/tsfresh_features_filt.csv.gz’
#
# ./data/tsfresh_feat 100%[===================>] 189.00M  58.2MB/s    in 3.2s
#
# 2021-04-24 16:13:53 (58.2 MB/s) - ‘./data/tsfresh_features_filt.csv.gz’ saved [198183650/198183650]

# %%
sign_features_filtered.shape
# Out:
# (2565, 11517)

# %% [markdown]
# ## Базовая модель

# %% [markdown]
# В результате у нас получилось очень много признаков (11516 или больше), давайте применим метод главных компонент, чтобы получить сжатое признаковое представление, сохранив при этом предиктивную силу в модели.

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from sklearn.neighbors import KNeighborsClassifier
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# %% [markdown]
# Создадим бейзлайн без уменьшения размерности. Гиперпараметры модели подбирались произвольно

# %%
# Подготовим данные на вход в модель

# признаки
X = sign_features_filtered.values

# классы
# y = sign_classes.target.values
y = sign_classes.values.ravel()

# %%
# Будем делать кросс-валидацию на 5 фолдов
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=123)

base_model = Pipeline([
    ('scaler', StandardScaler()),
    ('clf', KNeighborsClassifier(n_neighbors=9))
])

base_cv_scores = cross_val_score(base_model, X, y, cv=cv, scoring='accuracy')

# %%
base_cv_scores.mean()
# Out:
# 0.9196881091617932

# %% [markdown]
# ## Метод главных компонент (5 баллов)

# %% [markdown]
# * (1) Добавьте в пайплайн `base_model` шаг с методом главных компонент. Начиная с версии 0.18 в sklearn добавили разные солверы для PCA. Дополнитенльно задайте в модели следующие параметры: `svd_solder = "randomized"` и `random_state=123`. Остальные гиперпараметры модели и способ кросс-валидации оставьте без изменений
# * (1 + 2) Найдите такое наименьшее количество главных компонент, что качество нового пайплайна превыcит 90%. За +2 бала найдите решение не полным перебором
# * (1) Укажите долю объяснённой дисперсии при найденной настройке PCA  (для этого надо обучить PCA на всех данных). Долю объясненной диспекрии можно найти в атрибуте `explained_variance_ratio`

# %%
base_model = Pipeline([
    ('scaler', StandardScaler()),
    ('pca', PCA(n_components=70, svd_solver='randomized', random_state=123)),
    ('clf', KNeighborsClassifier(n_neighbors=9))
])

base_cv_scores = cross_val_score(base_model, X, y, cv=cv, scoring='accuracy')
base_cv_scores.mean()
# Out:
# 0.8966861598440545

# %%
# Перебор количества компонент (долго выполняется)
# min_compo компонеnents, score = 70, 0

# while score < .9:
#   min_components += 1
#   base_model = Pipeline([
#     ('scaler', StandardScaler()),
#     ('pca', PCA(n_components=min_components, svd_solver='randomized', random_state=123)),
#     ('clf', KNeighborsClassifier(n_neighbors=9))
#   ])
#   base_cv_scores = cross_val_score(base_model, X, y, cv=cv, scoring='accuracy')
#   score = base_cv_scores.mean()

# print('Числонт:', min_components, '\nКачество:', score.round(3))

# %% [markdown]
# В результате получим минимальное число компонент: 77, и соответствующее качество: 0.901

# %%
base_model = Pipeline([
    ('scaler', StandardScaler()),
    ('pca', PCA(n_components=77, svd_solver='randomized', random_state=123)),
    ('clf', KNeighborsClassifier(n_neighbors=9))
])

base_cv_scores = cross_val_score(base_model, X, y, cv=cv, scoring='accuracy')
base_cv_scores.mean()
# Out:
# 0.9009746588693958

# %%
# Найдем долю объясненной дисперсии
pipe = Pipeline([
    ('scaler', StandardScaler()),
    ('pca', PCA(n_components=77, svd_solver='randomized', random_state=123))
])
pipe.fit(X)['pca'].explained_variance_ratio_.sum()
# Out:
# 0.6167922915550423

# %% [markdown]
# # Задача про кластеризацию текстов

# %% [markdown]
# Рассмотрим коллекцию новостных сообщений за первую половину 2017 года. Про каждое новостное сообщение известны:
# * его заголовок и текст
# * дата его публикации
# * событие, о котором это новостное сообщение написано
# * его рубрика

# %%
df = pd.read_csv('./data/news.csv', encoding='utf8')
df.head()
# Out:
#                                                                                                   text  ...                   class
# 0   В ПЕТЕРБУРГЕ ПРОШЕЛ МИТИНГ ПРОТИВ ПЕРЕДАЧИ ИСААКИЕВСКОГО СОБОРА РПЦ В Санкт-Петербурге люди уст...  ...  Внутренняя политика РФ
# 1   Lenta.co, Москва, 14 января 2017 СИТУАЦИЯ С ПЕРЕДАЧЕЙ ИСААКИЕВСКОГО СОБОРА В ВЕДЕНИЕ РПЦ. ИСТОР...  ...  Внутренняя политика РФ
# 2   Аргументы и Факты (aif.ru), Москва, 14 января 2017 ОППОЗИЦИЯ ПРОВЕЛА МИТИНГ ПРОТИВ ПЕРЕДАЧИ ИСА...  ...  Внутренняя политика РФ
# 3   Google Новости ТОП, Москва, 14 января 2017 АКЦИЯ ПРОТИВ ПЕРЕДАЧИ ИСААКИЕВСКОГО СОБОРА РПЦ ПРОШЛ...  ...  Внутренняя политика РФ
# 4   Газета.Ru, Москва, 13 января 2017 В МОСКОВСКОЙ ПАТРИАРХИИ ПРОКОММЕНТИРОВАЛИ ПЕРЕДАЧУ ИСААКИЕВСК...  ...  Внутренняя политика РФ
#
# [5 rows x 4 columns]

# %%
df['class'] = df['class'].replace('Спорт ', 'Спорт')

# %%
df.loc[:, 'class'].value_counts()
# Out:
# Важные мировые события                           403
# Внутренняя политика РФ                           364
# Внутренняя политика РФ: оппозиция                277
# Спорт                                            202
# Теракты                                          200
# Международные отношения                          153
# Внутренняя политика: культура                    100
# Проишествия  РФ                                  100
# Международные отношения: Криминальная хроника     82
# Технологии                                        49
# Name: class, dtype: int64

# %% [markdown]
# Попробуем кластеризовать документы (каким-либо методом) и сравним полученное разбиение с данными рубликами с помощью ARI

# %% [markdown]
# ## Стандартная предобработка текстов

# %% [markdown]
# Ниже выполняется набор операций по предобработке текстов. Возможно на этом курсе про это не будет идти речь, однако идея довольно простая. Просто следите за комментариями =)

# %%
df.text[0] # Так выглядит первая статья до преобработки
# Out:
# ' В ПЕТЕРБУРГЕ ПРОШЕЛ МИТИНГ ПРОТИВ ПЕРЕДАЧИ ИСААКИЕВСКОГО СОБОРА РПЦ В Санкт-Петербурге люди устроили акцию протеста против передачи Исаакиевского собора в безвозмездное пользование РПЦ. Жители Петербурга собрались на Исаакиевской площади, чтобы высказаться против передачи Исаакиевского собора в безвозмездное пользование РПЦ, передает ТАСС. Акция проходит в формате встречи с депутатами Законодательного собрания города и не требует согласования с властями. Участники акции не используют какую-либо символику и плакаты, а также мегафоны или средства звукоусиления. По словам депутата Алексея Ковалева, на Исаакиевскую площадь пришло примерно тысяча человек. Перед участниками протеста выступили депутаты местного парламента Борис Вишневский и Максим Резник, которые заявили о том, что потребуют отмены решения Смольного. Вишневский сообщил, что акция будет проходить в виде встречи депутатов с избирателями. "Закон Санкт-Петербурга предоставляет нам право встречаться с избирателями, такую встречу мы и проведем, расскажем, как защищаем их интересы при передаче собора", - сказал парламентарий. В свою очередь директор музея "Исаакиевский собор" Николай Буров проинформировал, что собор в пятницу будет закрыт намного раньше в связи с акцией протеста. Он подчеркнул, что необходимо избежать стычек между сторонниками передачи собора и ее противниками. Ранее стало известно, что собор передадут в безвозмездное пользование на 49 лет Русской православной церкви в лице Московского патриархата, при этом он останется в собственности Петербурга. Тем временем, в Петербурге продолжается сбор подписей под петицией об отмене данного решения, под документом уже поставили подписи более 160 тысяч человек. Комментарии Другие интересные статьи: http://kontrastniy.ru/obshchestvo/838-v-peterburge-proshel-miting-protiv-peredachi-isaakievskogo-sobora-rpts.html'

# %%
import re

# Оставляем только кириллические символы
regex = re.compile(u"[А-Яа-я]+")

def words_only(text, regex=regex):
    return " ".join(regex.findall(text))


df.text = df.text.str.lower()
df.loc[:, 'text'] = df.text.apply(words_only)

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords

# Удаляем стоп-слова
mystopwords = stopwords.words('russian') + ['это', 'наш' , 'тыс', 'млн', 'млрд', u'также',  'т', 'д', '-', '-']

def  remove_stopwords(text, mystopwords = mystopwords):
    try:
        return u" ".join([token for token in text.split() if not token in mystopwords])
    except:
        return u""
    
df.text = df.text.apply(remove_stopwords)

# %%
# !pip install pymystem3
# !wget http://download.cdn.yandex.net/mystem/mystem-3.0-linux3.1-64bit.tar.gz
# !tar -xvf mystem-3.0-linux3.1-64bit.tar.gz
# !mkdir -p /root/.local/bin
# !cp mystem /root/.local/bin/mystem
# Out:
# Requirement already satisfied: pymystem3 in /usr/local/lib/python3.7/dist-packages (0.2.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from pymystem3) (2.23.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->pymystem3) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->pymystem3) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->pymystem3) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->pymystem3) (1.24.3)
# --2021-04-24 16:18:22--  http://download.cdn.yandex.net/mystem/mystem-3.0-linux3.1-64bit.tar.gz
# Resolving download.cdn.yandex.net (download.cdn.yandex.net)... 5.45.205.241, 5.45.205.245, 5.45.205.244, ...
# Connecting to download.cdn.yandex.net (download.cdn.yandex.net)|5.45.205.241|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: http://cache-man01i.cdn.yandex.net/download.cdn.yandex.net/mystem/mystem-3.0-linux3.1-64bit.tar.gz [following]
# --2021-04-24 16:18:22--  http://cache-man01i.cdn.yandex.net/download.cdn.yandex.net/mystem/mystem-3.0-linux3.1-64bit.tar.gz
# Resolving cache-man01i.cdn.yandex.net (cache-man01i.cdn.yandex.net)... 5.45.205.221, 2a02:6b8::3:221
# Connecting to cache-man01i.cdn.yandex.net (cache-man01i.cdn.yandex.net)|5.45.205.221|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16457938 (16M) [application/octet-stream]
# Saving to: ‘mystem-3.0-linux3.1-64bit.tar.gz.1’
#
# mystem-3.0-linux3.1 100%[===================>]  15.70M  7.91MB/s    in 2.0s
#
# 2021-04-24 16:18:25 (7.91 MB/s) - ‘mystem-3.0-linux3.1-64bit.tar.gz.1’ saved [16457938/16457938]
#
# mystem
# cp: cannot create regular file '/root/.local/bin/mystem': Text file busy

# %%
# %%time 
from pymystem3 import Mystem


# нормализуем текст
m = Mystem('/root/.local/bin/mystem')
def lemmatize(text, mystem=m):
    try:
        return "".join(m.lemmatize(text)).strip()  
    except:
        return " "

df.text = df.text.apply(lemmatize)
# Out:
# CPU times: user 5.06 s, sys: 298 ms, total: 5.36 s
# Wall time: 32.8 s

# %%
mystoplemmas = [u'который', u'прошлый', u'сей', u'свой', u'наш', u'мочь']

# Еще кое-что удаляем
def  remove_stoplemmas(text, mystoplemmas = mystoplemmas):
    try:
        return " ".join([token for token in text.split() if not token in mystoplemmas])
    except:
        return ""

df.text = df.text.apply(remove_stoplemmas)

# %%
df.text[0] # так выгладит первая статья после предобработки
# Out:
# 'петербург проходить митинг против передача исаакиевский собор рпц санкт петербург человек устраивать акция протест против передача исаакиевский собор безвозмездный пользование рпц житель петербург собираться исаакиевский площадь высказываться против передача исаакиевский собор безвозмездный пользование рпц передавать тасс акция проходить формат встреча депутат законодательный собрание город требовать согласование власть участник акция использовать какой либо символика плакат мегафон средство звукоусиление слово депутат алексей ковалев исаакиевский площадь приходить примерно тысяча человек участник протест выступать депутат местный парламент борис вишневский максим резник заявлять потребовать отмена решение смольный вишневский сообщать акция проходить вид встреча депутат избиратель закон санкт петербург предоставлять мы право встречаться избиратель такой встреча проводить рассказывать защищать интерес передача собор сказать парламентарий очередь директор музей исаакиевский собор николай буров проинформировать собор пятница закрывать намного рано связь акция протест подчеркивать необходимо избегать стычка сторонник передача собор противник ранее становиться известно собор передавать безвозмездный пользование год русский православный церковь лицо московский патриархат оставаться собственность петербург время петербург продолжаться сбор подпись петиция отмена данный решение документ поставлять подпись тысяча человек комментарий другой интересный статья'

# %% [markdown]
# ## Вычисление сходства (1 балл)

# %% [markdown]
# С помощью `TfidfVectorizer` и `pairwise_distances` расчитайте **косинусное** расстояние между всеми парами документов к корпусе.
#
# Про векторизацию текстов с помощью `CountVectorizer` или `TfidfVectorizer` можно почитать [тут](https://www.machinelearningmastery.ru/gentle-introduction-bag-words-model/)
#
# Запишите результат в переменную `S`

# %%
import seaborn as sns
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import pairwise_distances

# %%
vect = TfidfVectorizer()
texts = df.text.values

# %%
X = vect.fit_transform(texts)
S = pairwise_distances(X, metric='cosine')

# %%
plt.figure(figsize = (10,10))
sns.heatmap(data=S, cmap = 'Spectral').set(xticklabels=[],yticklabels=[])
# Out:
# [[], []]

# %% [markdown]
# Вы должны пронаблюдать, что между некоторыми текстами есть довольно высокое сходство по содержанию слов - мы видим, что вдоль диагонали матрицы попарых расстояний есть "блоки" по похожести.
#
# Нам конечно же повезло, так как тексты заранее были удачно упорядочены. В реальности такой живописной картины мы скорее всего не увидим.
#
# Попробуем их кластеризовать

# %% [markdown]
# ## DBSCAN (4 балла)
# * (2) Воспользуйтесь методикой оценки параметров для алгоритма DBSCAN. Не копипастите `min_pts = 2` из семинара! Используйте **косинусную** меру близости.
# * (1) Выделите кластеры. Для каждого кластера (кроме -1, если он будет) выведите несколько текстов и умозрительно определите его тематику. Можете подсмотреть в исходные тематики корпуса
# * (1) Оцените сходство с изначальными рубриками визуально (с помощью матрицы перемешивания) и с помощью [Adjusted Rand Index](https://en.wikipedia.org/wiki/Rand_index)

# %%
from sklearn.neighbors import NearestNeighbors
from sklearn.cluster import DBSCAN
from sklearn.metrics.cluster import adjusted_rand_score

# %%
# Оценка параметра эпсилон с помощью метода ближайших соседей
nn = NearestNeighbors(n_neighbors=39, metric='cosine')
nn.fit(X)
dist, idx = nn.kneighbors(X)
dist = np.sort(dist[:, -1])

plt.plot(dist)

# %% [markdown]
# Можем предположить, что оптимальный эпсилон лежит вблизи 0.7

# %%
# Подбор оптимальных параметров (долго выполняется)
# scores = np.empty((0, 3))
# for i in range(38, 42):
#   for e in np.arange(.66, .73, .001):
#     dbscan = DBSCAN(eps=e, min_samples=i, metric='cosine').fit(X)
#     scores = np.vstack((scores, [i, e, adjusted_rand_score(df.loc[:, 'class'], dbscan.labels_)]))

# print(scores[scores[:, 2].argsort()[-1]])

# %% [markdown]
# Получаем лучший результат при eps=.67, min_samples=39

# %%
dbscan = DBSCAN(eps=.67, min_samples=39, metric='cosine').fit(X)
labels = dbscan.labels_

# %%
# Посмотрим на выделенные кластеры
pd.set_option('display.max_colwidth', 100)
for i in np.unique(labels)[1:]:
  print('Label:', i) 
  print(df.text[labels == i].sample(5).to_string(index=False))
  print()
# Out:
# Label: 0
#  новость топ москва январь петербург проходить акция противник передача исаакиевский собор рпц мо...
#  москва январь платить петербуржец пользоваться рпц какой условие церковь получать источник русск...
#  тк звезда москва январь петербург идти акция против передача исаакиевский собор церковь санкт пе...
#  москва январь сколько объект недвижимость передавать рпц год год росимущество рассматривать заяв...
#  театрал москва январь экспонат извлекать музей использовать первоначальный назначение ситуация я...
#
# Label: 1
#  новость сегодня москва июль смена караул подводить итог большинство журналист политолог упоминат...
#  москва июнь прямой линия путин реакция западный сми сегодня состояться очередной прямой линия пр...
#  инвесткафе москва январь обама встречать трамп белый дом автор скрипниченко анастасия избранный ...
#  москва июнь путин разузнавать воздействие инопланетянин политика государство нтв планировать вес...
#  москва май меркель пообещать путин поговорить порошенко канцлер германия меркель пообещать прези...
#
# Label: 2
#  дэлайт новость москва февраль умирать виталий чуркин называть причина смерть постоянный представ...
#  национальный служба новость москва февраль умирать виталий чуркин постоянный представитель рф оо...
#  тасс москва февраль москвич нести цветок здание мид смоленский площадь память виталия чуркин сот...
#  дэлайт новость москва февраль умирать виталий чуркин причина смерть постпред россия оон известны...
#  москва февраль умирать виталий чуркин причина смерть постпред россия оон автор некрасов влад изв...
#
# Label: 3
#  москва март димон расследование фонд навальный тайный империя медведев фонд борьба коррупция але...
#  грань ру москва март дима везде дом фбк рассказывать тайный империя дмитрий медведев фонд борьба...
#  москва март финансовый имущественный империя дмитрий медведев источник друг путин трабер коррупц...
#  москва март фбк потребовать ск возбуждать уголовный дело отношение медведев автор волец алексей ...
#  радио свобода москва март димонгейт автор пономарев аля расследование фбк дмитрий медведев стано...
#
# Label: 4
#  экоград москва март умирать дэвид рокфеллер миллиардер капитан армия сша март возраст год сконча...
#  москва март умирать дэвид рокфеллер старый миллиардер мир дэвид рокфеллер старший скончаться воз...
#  москва март доживать год умирать сон умирать дэвид рокфеллер автор волец алексей сегодня станови...
#  газета москва март восемь сердце рокфеллер скончаться миллиардер дэвид рокфеллер перенести семь ...
#  вестник москва март олицетворение капитализм сша год жизнь умирать дэвид рокфеллер сша год жизнь...
#
# Label: 5
#  риа новость москва август ветеран альфа теракт испания показывать иго намерен сдаваться москва а...
#  риа новость москва август посольство испания подтверждать теракт пострадать россиянка москва авг...
#  москва март иго взять ответственность лондонский теракт террористический группировка исламский г...
#  москва май последствие ураган москва область медицинский помощь обращаться порядок сто семьдесят...
#  москва май правительство оказывать поддержка пострадавший ураган глава правительство россия дмит...
#  москва май собянин поручать течение два сутки ликвидировать последствие шквал москва мэр москва ...
#  москва май ск рф устанавливать обстоятельство гибель человек время ураган май фото иа росбалт ев...
#
# Label: 14
#  риа новость москва сентябрь жалоба нарушение выборы севастополь поступать москва сено риа новост...
#  риа новость москва сентябрь цик мордовия призывать признавать недействительный выборы один участ...
#  риа новость москва сентябрь международный наблюдатель обнаруживать нарушение выборы глава удмурт...
#  тасс москва сентябрь выборы сзфо уголовный дело целое спокойно тасс сентябрь тасс представитель ...
#  тасс москва сентябрь россия завершаться единый день голосование тасс сентябрь единый день голосо...

# %%
# Можем выделить тематики статей в кластерах
label_names = np.empty(labels.shape, dtype='object')
d = {-1: -1,
     0: 'Внутренняя политика РФ 1',
     1: 'Важные мировые события 1',
     2: 'Важные мировые события 2',
     3: 'Внутренняя политика РФ: оппозиция',
     4: 'Важные мировые события 3',
     5: 'Теракты',
     6: 'Международные отношения: Криминальная хроника',
     7: 'Внутренняя политика РФ: оппозиция',
     8: 'Технологии',
     9: 'Внутренняя политика: культура',
     10: 'Спорт',
     11: 'Внутренняя политика РФ 2',
     12: 'Важные мировые события 4',
     13: 'Проишествия РФ',
     14: 'Внутренняя политика РФ 3'}

for id, name in d.items():
  label_names[labels == id] = name

# %%
# Построим таблицу для сравнения с изначальными рубриками
tab = pd.crosstab(df.loc[:, 'class'], label_names, rownames=['Исходные темы'], colnames=['Выделенные кластеры'])
tab = tab.rename(columns={-1:'Выбросы'})
tab.style.set_table_styles(
    [{'selector': 'th', 'props': [('max-width', '200px')]},
     {'selector': 'th.col_heading', 'props': [('max-width', '80px'),
                                              ('height', '100px'),
                                              ('transform', 'rotateZ(-60deg)')
                                              ]}])
# Out:
# <style  type="text/css" >
#     #T_cbe0260a_a518_11eb_95bd_0242ac1c0002 th {
#           max-width: 200px;
#     }    #T_cbe0260a_a518_11eb_95bd_0242ac1c0002 th.col_heading {
#           max-width: 80px;
#           height: 100px;
#           transform: rotateZ(-60deg);
#     }</style><table id="T_cbe0260a_a518_11eb_95bd_0242ac1c0002" ><thead>    <tr>        <th class="index_name level0" >Выделенные кластеры</th>        <th class="col_heading level0 col0" >Выбросы</th>        <th class="col_heading level0 col1" >Важные мировые события 1</th>        <th class="col_heading level0 col2" >Важные мировые события 2</th>        <th class="col_heading level0 col3" >Важные мировые события 3</th>        <th class="col_heading level0 col4" >Важные мировые события 4</th>        <th class="col_heading level0 col5" >Внутренняя политика РФ 1</th>        <th class="col_heading level0 col6" >Внутренняя политика РФ 2</th>        <th class="col_heading level0 col7" >Внутренняя политика РФ 3</th>        <th class="col_heading level0 col8" >Внутренняя политика РФ: оппозиция</th>        <th class="col_heading level0 col9" >Внутренняя политика: культура</th>        <th class="col_heading level0 col10" >Международные отношения: Криминальная хроника</th>        <th class="col_heading level0 col11" >Проишествия РФ</th>        <th class="col_heading level0 col12" >Спорт</th>        <th class="col_heading level0 col13" >Теракты</th>        <th class="col_heading level0 col14" >Технологии</th>    </tr>    <tr>        <th class="index_name level0" >Исходные темы</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T
#                         <td id="T_cbe0260a_a518_11eb_95bd_0242ac1c0002row1_col11" class="data row1 col11" >0</td>
#                         <td id="T_cbe0260a_a518_11eb_95bd_0242ac1c0002row1_col12" class="data row1 col12" >0</td>
#                         <td id="T_cbe0260a_a518_11eb_95bd_0242ac1c0002row1_col13" class="data row1 col13" >0</td>
#                         <td id="T_cbe0260a_a518_11eb_95bd_0242ac1c0002row1_col14" class="data row1 col14" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_cbe0260a_a518_11eb_95bd_0242ac1c0002level0_row2" class="row_heading level0 row2" >Внутренняя политика РФ: оппозиция</th>
#                         <td id="T_cbe0260a_a518_11eb_95bd_0242ac1c0002row2_col0" class="data row2 col0" >53</td>
#                         <td id="T_cbe0260a_a518_11eb_95bd_0242ac1c0002row2_col1" class="data row2 col1" >1</td>
#                         <td id="T_cbe0260a_a518_11eb_95bd_0242ac1c0002row2_col2" class="data row2 col2" >0</td>
#                         <td id="T_cbe0260a_a518_11eb_95bd_0242ac1c0002row2_col3" class="data row2 col3" >0</td>
#                         <td id="T_cbe0260a_a518_11eb_95bd_0242ac1c0002row2_col4" class="data row2 col4" >0</td>
#                         <td id="T_cbe0260a_a518_11eb_95bd_0242ac1c0002row2_col5" class="data row2 col5" >0</td>
#                         <td id="T_cbe0260a_a518_11eb_95bd_0242ac1c0002row2_col6" class="data row2 col6" >0</td>
#                         <td id="T_cbe0260a_a518_11eb_95bd_0242ac1c0002row2_col7" class="data row2 col7" >0</td>
#                         <td id="T_cbe0260a_a518_11eb_95bd_0242ac1c0002row2_col8" class="data row2 col8" >223</td>
#                         <td id="T_cbe0260a_a518_11eb_95bd_0242ac1c0002row2_col9" class="data row2 col9" >0</td>
#                         <td id="T_cbe0260a_a518_11eb_95bd_0242ac1c0002row2_col10" class="data row2 col10" >0</td>
#                         <td id="T_cbe0260a_a518_11eb_95bd_0242ac1c0002row2_col11" class="data row2 col11" >0</td>
#                         <td id="T_cbe0260a_a518_11eb_95bd_0242ac1c0002row2_col12" class="data row2 col12" >0</td>
#                         <td id="T_cbe0260a_a518_11eb_95bd_0242ac1c0002row2_col13" class="data row2 col13" >0</td>
#                         <td id="T_cbe0260a_a518_11eb_95bd_0242ac1c0002row2_col14" class="data row2 col14" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_cbe0260a_a518_11eb_95bd_0242ac1c0002level0_row3" class="row_heading level0 row3" >Внутренняя политика: культура</th>
#                         <td id="T_cbe0260a_a518_11eb_95bd_0242ac1c0002row3_col0" class="data row3 col0" >1</td>
#                         <td i

# %%
# Посчитаем Adjusted Rand Index 
adjusted_rand_score(df.loc[:, 'class'], labels)
# Out:
# 0.46640372214194986

# %% [markdown]
# Таким образом, удалось явно выделить большую часть категорий (хоть и с некотором количеством выбросов), однако некоторые темы оказались разбиты на несколько кластеров. Можно предположить, что причина - в обширности этих тематик ("Важные мировые события" и "Внутренняя политика РФ"), и из-за этого алгоритм увидел несколько подразделов в них. Кроме того, несколько близких по смыслу тем оказались объединены в один кластер (части "Важных мировых событий" и "Внутренней политики РФ" с "Международными отношениями"). В рубрике "Спорт" получилось большое количество выбросов. Возможное объяснение этих аномалий - разница плотностей реальных кластеров, с которой DBSCAN работает плохо.
